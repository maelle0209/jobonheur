# %%
# Importer les bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install chardet


# Chemin du fichier CSV (remplace-le si nécessaire)
file_path = '/content/chomage.csv'

# Lire le fichier CSV avec Pandas
data = pd.read_csv(file_path, sep=';', encoding='Windows-1254')

# Afficher les premières lignes pour vérifier le contenu
print(data.head())

# Vérifier la structure du fichier
print(data.info())
# Out:
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (5.2.0)
#       Sexe et ƒge 1975-T1 1975-T2 1975-T3 1975-T4 1976-T1 1976-T2 1976-T3  \
# 0          Femmes     4.6     4.9     5.2     5.5     5.8     5.9     5.8
# 1       15-24 ans     9.8    10.4    11.1    11.8    12.8    13.1    12.7
# 2       25-49 ans     3.3     3.5     3.7     3.9     4.0     4.0     4.0
# 3  50 ans ou plus     2.1     2.2     2.4     2.5     2.6     2.7     2.8
# 4          Hommes     2.3     2.6     2.8     2.9     2.9     2.8     2.7
#
#   1976-T4 1977-T1  ... 2022-T2 2022-T3 2022-T4 2023-T1 2023-T2 2023-T3  \
# 0     5.8     6.1  ...     7.2     7.0     6.9     6.8     7.1     7.4
# 1    12.6    13.5  ...    17.3    15.7    14.8    15.6    16.0    16.0
# 2     4.0     4.1  ...     6.6     6.4     6.4     6.3     6.6     7.2
# 3     3.0     3.2  ...     5.0     5.2     5.2     5.0     5.1     5.2
# 4     2.7     2.9  ...     7.6     7.5     7.3     7.4     7.4     7.4
#
#   2023-T4 2024-T1 2024-T2 2024-T3
# 0     7.4     7.3     7.4     7.2
# 1    16.7    17.0    18.2    20.0
# 2     7.1     7.0     6.8     6.3
# 3     4.9     4.9     5.0     4.8
# 4     7.7     7.6     7.3     7.6
#
# [5 rows x 200 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Columns: 200 entries, Sexe et ƒge to 2024-T3
# dtypes: float64(87), object(113)
# memory usage: 20.4+ KB
# None

# %%
import chardet

# Ouvrir le fichier en mode binaire pour la détection de l'encodage
with open('/content/chomage.csv', 'rb') as f:
    result = chardet.detect(f.read())

# Afficher le résultat
print(result)
# Out:
# {'encoding': 'Windows-1254', 'confidence': 0.9250835525064276, 'language': 'Turkish'}

# %%
import pandas as pd

# Essayer différents encodages
encodings = ['utf-8', 'ISO-8859-1', 'latin1', 'windows-1254']
for enc in encodings:
    try:
        data = pd.read_csv('/content/chomage.csv', encoding=enc)
        print(f"Fichier chargé avec succès avec l'encodage : {enc}")
        break
    except Exception as e:
        print(f"Erreur avec l'encodage {enc}: {e}")
# Out:
# Erreur avec l'encodage utf-8: 'utf-8' codec can't decode byte 0x83 in position 8: invalid start byte
# Fichier chargé avec succès avec l'encodage : ISO-8859-1

# %%
data = pd.read_csv('/content/chomage.csv', encoding='Windows-1254', sep=';')
print(data.head())
# Out:
#       Sexe et ƒge 1975-T1 1975-T2 1975-T3 1975-T4 1976-T1 1976-T2 1976-T3  \
# 0          Femmes     4.6     4.9     5.2     5.5     5.8     5.9     5.8
# 1       15-24 ans     9.8    10.4    11.1    11.8    12.8    13.1    12.7
# 2       25-49 ans     3.3     3.5     3.7     3.9     4.0     4.0     4.0
# 3  50 ans ou plus     2.1     2.2     2.4     2.5     2.6     2.7     2.8
.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    8.292308   8.307692   8.438462   8.584615   8.692308   8.792308
# std     5.117203   5.022194   5.150006   5.183764   5.298500   5.603639
# min     1.800000   1.800000   1.800000   1.800000   1.800000   1.800000
# 25%     5.200000   5.400000   5.100000   5.200000   5.100000   5.200000
# 50%     6.500000   6.400000   6.600000   7.200000   7.100000   7.000000
# 75%     7.300000   7.400000   7.400000   7.400000   7.700000   7.600000
# max    18.700000  17.800000  18.100000  18.400000  18.300000  19.300000
#
#          2024-T2    2024-T3
# count  13.000000  13.000000
# mean    8.661538   9.000000
# std     5.502051   6.303306
# min     1.700000   1.700000
# 25%     5.100000   4.800000
# 50%     6.800000   6.900000
# 75%     7.400000   7.600000
# max    18.200000  20.000000
#
# [8 rows x 87 columns]

# %%
# Reformater les données pour un format "long"
df_long = pd.melt(data, id_vars=["Sexe et ƒge"], var_name="Trimestre", value_name="Taux")

# Séparer le "Sexe et ƒge" en deux colonnes
df_long[['Sexe', 'Âge']] = df_long['Sexe et ƒge'].str.extract(r'(Femmes|Hommes|Ensemble)?(.*)')

# Remplir les lignes "Sexe" manquantes par les valeurs précédentes
df_long['Sexe'] = df_long['Sexe'].fillna(method='ffill')

# Vérifiez le résultat
print(df_long.head())
# Out:
#       Sexe et ƒge Trimestre Taux    Sexe             Âge
# 0          Femmes   1975-T1  4.6  Femmes
# 1       15-24 ans   1975-T1  9.8  Femmes       15-24 ans
# 2       25-49 ans   1975-T1  3.3  Femmes       25-49 ans
# 3  50 ans ou plus   1975-T1  2.1  Femmes  50 ans ou plus
# 4          Hommes   1975-T1  2.3  Hommes
# <ipython-input-8-3930bbf91967>:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_long['Sexe'] = df_long['Sexe'].fillna(method='ffill')

# %%
# Vérifier le type de la colonne "Trimestre"
print(df_long.dtypes)

# Si "Trimestre" n'est pas une chaîne, convertissez-la
df_long["Trimestre"] = df_long["Trimestre"].astype(str)
# Out:
# Sexe et ƒge    object
# Trimestre      object
# Taux           object
# Sexe           object
# Âge            object
# dtype: object

# %%
# Vérifier les données manquantes
print(df_long.isnull().sum())

# Afficher les lignes problématiques
print(df_long[df_long.isnull().any(axis=1)])
# Out:
# Sexe et ƒge    0
# Trimestre      0
# Taux           0
# Sexe           0
# Âge            0
# dtype: int64
# Empty DataFrame
# Columns: [Sexe et ƒge, Trimestre, Taux, Sexe, Âge]
# Index: []

# %%
# Affichez les types des colonnes
print(df_long)

# Affichez un aperçu des 10 premières lignes
print(df_long.head(10))
# Out:
#                           Sexe et ƒge Trimestre  Taux      Sexe  \
# 0                              Femmes   1975-T1   4.6    Femmes
# 1                           15-24 ans   1975-T1   9.8    Femmes
# 2                           25-49 ans   1975-T1   3.3    Femmes
# 3                      50 ans ou plus   1975-T1   2.1    Femmes
# 4                              Hommes   1975-T1   2.3    Hommes
# ...                               ...       ...   ...       ...
# 2582                         Ensemble   2024-T3   7.4  Ensemble
# 2583                        15-24 ans   2024-T3  19.7  Ensemble
# 2584                        25-49 ans   2024-T3   6.6  Ensemble
# 2585                   50 ans ou plus   2024-T3   4.7  Ensemble
# 2586  Taux de ch“mage de longue dur‚e   2024-T3   1.7  Ensemble
#
#                                   Âge
# 0
# 1                           15-24 ans
# 2                           25-49 ans
# 3                      50 ans ou plus
# 4
# ...                               ...
# 2582
# 2583                        15-24 ans
# 2584                        25-49 ans
# 2585                   50 ans ou plus
# 2586  Taux de ch“mage de longue dur‚e
#
# [2587 rows x 5 columns]
#       Sexe et ƒge Trimestre Taux      Sexe             Âge
# 0          Femmes   1975-T1  4.6    Femmes
# 1       15-24 ans   1975-T1  9.8    Femmes       15-24 ans
# 2       25-49 ans   1975-T1  3.3    Femmes       25-49 ans
# 3  50 ans ou plus   1975-T1  2.1    Femmes  50 ans ou plus
# 4          Hommes   1975-T1  2.3    Hommes
# 5       15-24 ans   1975-T1  4.8    Hommes       15-24 ans
# 6       25-49 ans   1975-T1  1.7    Hommes       25-49 ans
# 7  50 ans ou plus   1975-T1  1.8    Hommes  50 ans ou plus
# 8        Ensemble   1975-T1  3.2  Ensemble
# 9       15-24 ans   1975-T1  7.0  Ensemble       15-24 ans

# %%
# Conversion de "Trimestre" en chaîne si ce n'est pas déjà le cas
df_long["Trimestre"] = df_long["Trimestre"].astype(str)

# %%
# Convertir la colonne "Taux" en float
df_long["Taux"] = pd.to_numeric(df_long["Taux"], errors="coerce")

# Vérifiez si la conversion a fonctionné
print(df_long.dtypes)
print(df_long.head())
# Out:
# Sexe et ƒge     object
# Trimestre       object
# Taux           float64
# Sexe            object
# Âge             object
# dtype: object
#       Sexe et ƒge Trimestre  Taux    Sexe             Âge
# 0          Femmes   1975-T1   4.6  Femmes
# 1       15-24 ans   1975-T1   9.8  Femmes       15-24 ans
# 2       25-49 ans   1975-T1   3.3  Femmes       25-49 ans
# 3  50 ans ou plus   1975-T1   2.1  Femmes  50 ans ou plus
# 4          Hommes   1975-T1   2.3  Hommes

# %%
df_long.loc[:, "Trimestre"] = df_long["Trimestre"].astype(str)

# %%
df_long = df_long.copy()
df_long["Trimestre"] = df_long["Trimestre"].astype(str)

# %%
df_long["Taux"] = pd.to_numeric(df_long["Taux"], errors="coerce")
print(df_long["Taux"].isna().sum())
# Out:
# 112

# %%
# Afficher les lignes où la colonne "Taux" est NaN
print(df_long[df_long["Taux"].isna()])
# Out:
#                           Sexe et ƒge Trimestre  Taux      Sexe  \
# 12    Taux de ch“mage de longue dur‚e   1975-T1   NaN  Ensemble
# 25    Taux de ch“mage de longue dur‚e   1975-T2   NaN  Ensemble
# 38    Taux de ch“mage de longue dur‚e   1975-T3   NaN  Ensemble
# 51    Taux de ch“mage de longue dur‚e   1975-T4   NaN  Ensemble
# 64    Taux de ch“mage de longue dur‚e   1976-T1   NaN  Ensemble
# ...                               ...       ...   ...       ...
# 1403  Taux de ch“mage de longue dur‚e   2001-T4   NaN  Ensemble
# 1416  Taux de ch“mage de longue dur‚e   2002-T1   NaN  Ensemble
# 1429  Taux de ch“mage de longue dur‚e   2002-T2   NaN  Ensemble
# 1442  Taux de ch“mage de longue dur‚e   2002-T3   NaN  Ensemble
# 1455  Taux de ch“mage de longue dur‚e   2002-T4   NaN  Ensemble
#
#                                   Âge
# 12    Taux de ch“mage de longue dur‚e
# 25    Taux de ch“mage de longue dur‚e
# 38    Taux de ch“mage de longue dur‚e
# 51    Taux de ch“mage de longue dur‚e
# 64    Taux de ch“mage de longue dur‚e
# ...                               ...
# 1403  Taux de ch“mage de longue dur‚e
# 1416  Taux de ch“mage de longue dur‚e
# 1429  Taux de ch“mage de longue dur‚e
# 1442  Taux de ch“mage de longue dur‚e
# 1455  Taux de ch“mage de longue dur‚e
#
# [112 rows x 5 columns]

# %%
df_long = df_long.dropna(subset=["Taux"])

# %%
print(df_long["Taux"].isna().sum())
# Out:
# 0

# %%
print(df_long.dtypes)
# Out:
# Sexe et ƒge     object
# Trimestre       object
# Taux           float64
# Sexe            object
# Âge             object
# dtype: object

# %%
import plotly.express as px

# Filtrer les données pour exclure le chômage de longue durée et les tranches indésirables
df_age_filtered = df_long[df_long['Âge'] != "Longue durée"]  # Exclure "Longue durée"
df_age_avg = df_age_filtered.groupby("Âge", as_index=False)['Taux'].mean()

# Exclure la première et la dernière tranche d'âge
df_age_avg_filtered = df_age_avg.iloc[1:-1]  # Suppression de la première et de la dernière ligne

# Créer un graphique par tranche d'âge
fig_age_only = px.bar(
    df_age_avg_filtered,
    x="Âge",
    y="Taux",
    title="Taux de chômage moyen par tranche d'âge",
    labels={"Âge": "Tranche d'âge", "Taux": "Taux de chômage (%)"},
    color="Âge",  # Coloration automatique par tranche d'âge
    text="Taux",  # Afficher les valeurs sur les barres
)

# Personnalisation du graphique
fig_age_only.update_layout(
    font=dict(size=14, family="Arial"),
    plot_bgcolor="white",
    xaxis_title="Tranche d'âge",
    yaxis_title="Taux de chômage (%)",
)

# Ajouter des annotations aux barres pour plus de clarté
fig_age_only.update_traces(texttemplate='%{text:.2f}%', textposition='outside')

# Affichage du graphique
fig_age_only.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec1cc9c3-ea00-4de5-b473-2f76f205fe86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec1cc9c3-ea00-4de5-b473-2f76f205fe86")) {                    Plotly.newPlot(                        "ec1cc9c3-ea00-4de5-b473-2f76f205fe86",                        [{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=%{x}\u003cbr\u003eTaux de chômage (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"15-24 ans","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"15-24 ans","offsetgroup":"15-24 ans","orientation":"v","showlegend":true,"text":[20.073031825795645],"textposition":"outside","x":["15-24 ans"],"xaxis":"x","y":[20.073031825795645],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}%"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=%{x}\u003cbr\u003eTaux de chômage (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25-49 ans","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"25-49 ans","offsetgroup":"25-49 ans","orientation":"v","showlegend":true,"text":[7.213400335008375],"textposition":"outside","x":["25-49 ans"],"xaxis":"x","y":[7.213400335008375],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}%"},{"alignmentgroup":"True","hovertemplate":"Tranche d'âge=%{x}\u003cbr\u003eTaux de chômage (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"50 ans ou plus","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"50 ans ou plus","offsetgroup":"50 ans ou plus","orientation":"v","showlegend":true,"text":[5.3105527638190955],"textposition":"outside","x":["50 ans ou plus"],"xaxis":"x","y":[5.3105527638190955],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}%"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...

# %%
df_long['Année'] = df_long['Trimestre'].str[:4]

# %%
# Filtrer les données pour une année donnée (par exemple 2020)
df_2020_sexe = df_long[df_long['Année'] == "2020"].groupby("Sexe", as_index=False)['Taux'].mean()

# Diagramme en secteurs
fig_sexe = px.pie(
    df_2020_sexe,
    values="Taux",
    names="Sexe",
    title="Répartition des taux de chômage par sexe en 2020",
    labels={"Taux": "Taux de chômage (%)", "Sexe": "Sexe"},
)

# Personnalisation
fig_sexe.update_traces(textinfo="percent+label")  # Ajouter les pourcentages et labels
fig_sexe.update_layout(
    font=dict(size=14, family="Arial"),
    plot_bgcolor="white",
)

fig_sexe.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="83396b90-9c93-4f14-b0b8-4961c07dc1cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83396b90-9c93-4f14-b0b8-4961c07dc1cb")) {                    Plotly.newPlot(                        "83396b90-9c93-4f14-b0b8-4961c07dc1cb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Sexe=%{label}\u003cbr\u003eTaux de chômage (%)=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Ensemble","Femmes","Hommes"],"legendgroup":"","name":"","showlegend":true,"values":[8.825,10.96875,10.20625],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"co ...

# %%
import plotly.express as px

# Filtrer les données pour les femmes de 15-24 ans dans df_long
df_femmes_15_24 = df_long[(df_long['Âge'] == '15-24 ans') & (df_long['Sexe'] == 'Femmes')]

# Créer un graphique interactif avec Plotly
fig = px.line(
    df_femmes_15_24,  # Utiliser le DataFrame filtré
    x="Trimestre",
    y="Taux",
    markers=True,
    title="Évolution du taux de chômage des femmes 15-24 ans (1975-2024)",
    labels={"Trimestre": "Trimestre", "Taux": "Taux de chômage (%)"},
)

# Personnalisation du graphique : Titre, axes, et style
fig.update_layout(
    title="Évolution du taux de chômage des femmes 15-24 ans (1975-2024)",
    xaxis_title="Trimestre",
    yaxis_title="Taux de chômage (%)",
    xaxis=dict(
        tickangle=45,  # Rotation des ticks
        tickmode="array",  # Pour gérer les labels manuellement
        tickvals=df_femmes_15_24['Trimestre'][::5],  # Afficher moins de ticks si besoin
    ),
    font=dict(family="Arial", size=14),
)

# Exporter le graphique en HTML interactif pour l'intégrer directement sur un site web
fig.write_html("graphique_interactif.html")

# Affichage du graphique
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="555600c8-e3d9-4aa9-99ab-79e5c59384ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("555600c8-e3d9-4aa9-99ab-79e5c59384ef")) {                    Plotly.newPlot(                        "555600c8-e3d9-4aa9-99ab-79e5c59384ef",                        [{"hovertemplate":"Trimestre=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1975-T1","1975-T2","1975-T3","1975-T4","1976-T1","1976-T2","1976-T3","1976-T4","1977-T1","1977-T2","1977-T3","1977-T4","1978-T1","1978-T2","1978-T3","1978-T4","1979-T1","1979-T2","1979-T3","1979-T4","1980-T1","1980-T2","1980-T3","1980-T4","1981-T1","1981-T2","1981-T3","1981-T4","1982-T1","1982-T2","1982-T3","1982-T4","1983-T1","1983-T2","1983-T3","1983-T4","1984-T1","1984-T2","1984-T3","1984-T4","1985-T1","1985-T2","1985-T3","1985-T4","1986-T1","1986-T2","1986-T3","1986-T4","1987-T1","1987-T2","1987-T3","1987-T4","1988-T1","1988-T2","1988-T3","1988-T4","1989-T1","1989-T2","1989-T3","1989-T4","1990-T1","1990-T2","1990-T3","1990-T4","1991-T1","1991-T2","1991-T3","1991-T4","1992-T1","1992-T2","1992-T3","1992-T4","1993-T1","1993-T2","1993-T3","1993-T4","1994-T1","
2","2017-T3","2017-T4","2018-T1","2018-T2","2018-T3","2018-T4","2019-T1","2019-T2","2019-T3","2019-T4","2020-T1","2020-T2","2020-T3","2020-T4","2021-T1","2021-T2","2021-T3","2021-T4","2022-T1","2022-T2","2022-T3","2022-T4","2023-T1","2023-T2","2023-T3","2023-T4","2024-T1","2024-T2","2024-T3"],"xaxis":"x","y":[3.3,3.5,3.7,3.9,4.0,4.0,4.0,4.0,4.1,4.3,4.4,4.4,4.3,4.2,4.4,4.5,4.5,4.6,4.7,4.8,4.9,5.0,5.0,5.2,5.5,5.8,5.9,6.0,6.0,6.1,6.2,6.2,6.2,6.1,6.2,6.4,6.7,6.9,7.0,7.2,7.4,7.6,7.7,7.7,7.7,7.9,8.2,8.4,8.7,8.9,8.8,8.9,8.9,8.8,9.1,9.1,9.1,8.9,8.8,8.7,8.6,8.6,8.5,8.5,8.4,8.4,8.7,9.0,9.2,9.4,9.5,9.5,9.6,9.8,10.0,10.3,10.6,10.7,10.7,10.5,10.3,10.2,10.1,10.2,10.5,10.6,10.6,10.5,10.5,10.6,10.7,10.7,10.6,10.5,10.5,10.5,10.5,10.4,10.2,9.9,9.6,9.3,9.1,8.8,8.7,8.5,8.4,8.2,8.0,8.0,8.1,8.1,8.6,8.6,8.4,8.6,8.9,8.6,8.7,8.6,8.4,8.7,8.7,9.0,8.9,8.2,8.5,7.6,7.7,7.6,7.6,6.9,6.6,6.8,6.9,7.3,7.7,8.1,8.3,8.3,8.3,8.0,8.1,8.6,8.4,8.3,8.6,8.4,8.7,8.9,8.8,8.8,9.0,9.2,8.9,9.0,8.6,9.1,9.2,9.3,9.1,9.0,9.0,8.9,8.9,8.7,8.7,9.1,8.9,8.6,9.0,8.1,8.7,8.5,8.2,7.9,7.8,7.6,7.5,7.1,7.1,5.9,8.0,7.1,7.3,7.2,7.3,6.9,6.8,6.6,6.4,6.4,6.3,6.6,7.2,7.1,7.0,6.8,6.3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %%
# Filtrer les données pour les hommes de 15-24 ans dans df_long
df_hommes_15_24 = df_long[(df_long['Âge'] == '15-24 ans') & (df_long['Sexe'] == 'Hommes')]

# Créer un graphique interactif pour les hommes 15-24 ans
fig = px.line(
    df_hommes_15_24,
    x="Trimestre",
    y="Taux",
    markers=True,
    title="Évolution du taux de chômage des hommes 15-24 ans (1975-2024)",
    labels={"Trimestre": "Trimestre", "Taux": "Taux de chômage (%)"},
)

# Personnalisation du graphique
fig.update_layout(
    title="Évolution du taux de chômage des hommes 15-24 ans (1975-2024)",
    xaxis_title="Trimestre",
    yaxis_title="Taux de chômage (%)",
    xaxis=dict(
        tickangle=45,
        tickmode="array",
        tickvals=df_hommes_15_24['Trimestre'][::5],  # Afficher moins de ticks
    ),
    font=dict(family="Arial", size=14),
)

# Affichage du graphique
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fe03943-fe3b-41f3-a0b4-323ba61c2db9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fe03943-fe3b-41f3-a0b4-323ba61c2db9")) {                    Plotly.newPlot(                        "6fe03943-fe3b-41f3-a0b4-323ba61c2db9",                        [{"hovertemplate":"Trimestre=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["
3,18.9,19.5,20.2,19.9,18.9,17.5,16.2,15.4,14.8,14.4,14.2,14.2,14.8,15.3,15.6,15.9,16.6,16.9,16.0,17.8,18.4,19.3,19.2,19.0,19.5,19.4,19.4,19.0,19.8,19.6,21.1,20.8,19.0,21.0,19.2,18.8,18.2,17.6,16.7,17.8,19.0,20.2,22.6,24.0,24.2,24.4,23.5,21.7,23.1,20.4,21.1,21.5,21.1,21.9,22.6,23.7,24.4,25.6,25.1,24.1,23.6,22.6,23.2,24.6,24.5,25.4,25.5,24.4,24.9,25.2,25.3,24.1,23.8,23.7,22.8,23.1,21.9,21.4,21.1,21.3,21.8,19.2,20.8,20.2,18.8,20.5,19.0,21.0,19.9,19.2,20.8,19.6,18.2,17.2,17.5,18.9,18.9,18.7,17.8,18.1,18.4,18.3,19.3,17.7,19.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...

# %%
import pandas as pd
import plotly.express as px

# Extraire l'année à partir de la colonne 'Trimestre' (par exemple '1975-T1' => '1975')
df_long['Année'] = df_long['Trimestre'].str[:4]

# Calculer la moyenne du taux de chômage par année et par sexe
df_moyenne_par_annee = df_long.groupby(['Année', 'Sexe', 'Âge'], as_index=False)['Taux'].mean()

# Créer un graphique interactif pour comparer les moyennes annuelles
fig = px.line(
    df_moyenne_par_annee,
    x="Année",
    y="Taux",
    color="Sexe",  # Séparation par sexe
    markers=True,
    title="Comparaison des taux de chômage annuels hommes et femmes 15-24 ans (1975-2024)",
    labels={"Année": "Année", "Taux": "Taux de chômage (%)", "Sexe": "Sexe"},
)

# Personnalisation du graphique pour améliorer la lisibilité
fig.update_layout(
    title="Comparaison des taux de chômage annuels hommes et femmes 15-24 ans (1975-2024)",
    xaxis_title="Année",
    yaxis_title="Taux de chômage (%)",
    xaxis=dict(
        tickangle=45,  # Rotation des ticks pour éviter la superposition
        tickmode="array",  # Contrôle des valeurs de l'axe X
        tickvals=df_moyenne_par_annee['Année'][::2],  # Afficher un tick tous les 2 ans
        showgrid=True  # Afficher les lignes de grille pour faciliter la lecture
    ),
    yaxis=dict(
        showgrid=True  # Ajouter les lignes de grille sur l'axe Y
    ),
    font=dict(family="Arial", size=14),  # Taille de la police
    legend=dict(
        title="Sexe",
        font=dict(size=12)
    ),
    plot_bgcolor="white",  # Fond blanc pour plus de clarté
    paper_bgcolor="white",  # Fond blanc de la page
)

# Affichage du graphique
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7ce2a90-c959-462b-b31f-bbb5ec908949" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7ce2a90-c959-462b-b31f-bbb5ec908949")) {                    Plotly.newPlot(                        "a7ce2a90-c959-462b-b31f-bbb5ec908949",                        [{"hovertemplate":"Sexe=Ensemble\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensemble","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensemble","orientation":"v","showlegend":true,"x":["1975","1975","1975","1975","1976","1976","1976","1976","1977","1977","1977","1977","1978","1978","1978","1978","1979","1979","1979","1979","1980","1980","1980","1980","1981","1981","1981","1981","1982","1982","1982","1982","1983","1983","1983","1983","1984","1984","1984","1984","1985","1985","1985","1985","1986","1986","1986","1986","1987","1987","1987","1987","1988","1988","1988","1988","1989","1989","1989","1989","1990","1990","1990","1990","1991","1991","1991","1991","1992","1992","1992","1992","1993","1993","1993","1993","1994","1994","1994","1994","1995","

    yaxis_title="Taux de chômage (%)",
    xaxis=dict(tickangle=45, tickmode="array", tickvals=df_age_moyenne_annuelle['Année'][::2]),
    font=dict(family="Arial", size=14),
    plot_bgcolor="white",
    paper_bgcolor="white",
)

# Affichage
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4bfd84d7-1603-412e-a7b4-66ee80285821" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bfd84d7-1603-412e-a7b4-66ee80285821")) {                    Plotly.newPlot(                        "4bfd84d7-1603-412e-a7b4-66ee80285821",                        [{"hovertemplate":"Tranche d'âge=\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[3.766666666666667,4.191666666666666,4.691666666666666,4.891666666666667,5.466666666666666,5.8500000000000005,6.841666666666666,7.366666666666667,7.658333333333334,8.833333333333334,9.275,9.258333333333333,9.375,9.025,8.383333333333333,8.158333333333333,8.325000000000001,9.141666666666667,10.108333333333333,10.683333333333332,10.033333333333333,10.533333333333333,10.683333333333332,10.258333333333333,9.983333333333333,8.591666666666667,7.808333333333334,7.916666666666667,8.55,8.9,8.908333333333333,8.875,8.016666666666667,7.425,9.125,9.283333333333333,9.216666666666667,9.783333333333333,10.299999999999999,10.266666666666667,10.35,10.041666666666666,9.408333333333333,9.025,8.424999999999999,8.041666666666666,7.858333333333333,7.283333333333334,7.316666666666666,7.3999999999999995],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tranche d'âge=15-24 ans\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"15-24 ans","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"15-24 ans","orientation":"v","showlegend":true,"x":["1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[8.041666666666666,9.208333333333334,10.683333333333332,11.166666666666666,12.708333333333334,14.183333333333332,16.591666666666665,17.883333333333333,18.833333333333332,22.508333333333336,22.5,21.158333333333335,20.133333333333333,18.925,16.991666666666667,17.083333333333332,17.758333333333333,19.349999999999998,22.224999999999998,23.925,22.025000000000002,23.366666666666664,23.833333333333332,22.416666666666668,22.233333333333334,18.033333333333335,17.133333333333333,17.95,20.208333333333332,21.891666666666666,22.474999999999998,23.741666666666664,21.033333333333335,20.3,25.09166666666667,24.883333333333336,24.275000000000002,25.900000000000002,26.583333333333332,25.733333333333334,26.166666666666668,26.058333333333334,23.575,22.125,20.816666666666666,21.616666666666664,18.933333333333334,17.275,17.14166666666667,18.61111111111111],"yaxis":"y","type":"scatter"},{"hovertemplate":"Tranche d'âge=25-49 ans\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"25-49 ans","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"25-49 ans","orientation":"v","showlegend":true,"x":["1975","1976","1977","1978","1979","1980","1981","1982"," ...

# %%
# Calculer la moyenne annuelle par sexe et tranche d'âge
df_sexe_age_moyenne_annuelle = df_long.groupby(['Année', 'Sexe', 'Âge'], as_index=False)['Taux'].mean()

# Vérification des tranches d'âge disponibles
print("Tranches d'âge disponibles :", df_sexe_age_moyenne_annuelle['Âge'].unique())

# Exclure les tranches indésirables
ages_a_exclure = ['Taux de ch“mage de longue dur‚e']  # Ajustez ici si nécessaire

# Filtrer le DataFrame pour exclure les tranches indésirables
df_sexe_age_filtre = df_sexe_age_moyenne_annuelle[
    ~df_sexe_age_moyenne_annuelle['Âge'].isin(ages_a_exclure)
]

# Vérification des tranches après filtrage
print("Tranches d'âge après filtrage :", df_sexe_age_filtre['Âge'].unique())

# Créer un graphique interactif
fig = px.line(
    df_sexe_age_filtre,
    x="Année",
    y="Taux",
    color="Sexe",  # Comparaison entre hommes et femmes
    facet_col="Âge",  # Créer des sous-graphiques pour chaque tranche d'âge
    markers=True,
    title="Comparaison des taux de chômage hommes vs femmes par tranche d'âge (1975-2024)",
    labels={"Année": "Année", "Taux": "Taux de chômage (%)", "Sexe": "Sexe"},
)

# Personnalisation
fig.update_layout(
    xaxis_title="Année",
    yaxis_title="Taux de chômage (%)",
    font=dict(family="Arial", size=14),
    plot_bgcolor="white",
    paper_bgcolor="white",
)

# Affichage
fig.show()
# Out:
# Tranches d'âge disponibles : ['' '15-24 ans' '25-49 ans' '50 ans ou plus'
#  'Taux de ch“mage de longue dur‚e']
# Tranches d'âge après filtrage : ['' '15-24 ans' '25-49 ans' '50 ans ou plus']
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8bc27892-a684-49be-8d8d-1aebc1163d67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bc27892-a684-49be-8d8d-1aebc1163d67")) {                    Plotly.newPlot(                        "8bc27892-a684-49be-8d8d-1aebc1163d67",                        [{"hovertemplate":"Sexe=Ensemble\u003cbr\u003eÂge=\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensemble","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensemble","orientation":"v","showlegend":true,"x":["1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"xaxis":"x","y":[3.6,3.975,4.5,4.7,5.25,5.6,6.6,7.15,7.475,8.65,9.1,9.1,9.225,8.875,8.225,8.025,8.2,9.0,10.05,10.6,9.95,10.45,10.625,10.2,9.95,8.55,7.75,7.875,8.525,8.875,8.875,8.875,8.025,7.425,9.125,9.275,9.2,9.8,10.3,10.275,10.35,10.025,9.4,9.025,8.425,8.05,7.85,7.275,7.3,7.3999999999999995],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sexe=Ensemble\u003cbr\u003eÂge=15-24 ans\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensemble","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensemble","orientation":"v","showlegend":false,"x":["1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"xaxis":"x2","y":[7.85,9.0,10.475,10.925,12.45,13.825,16.275,17.525,18.475,22.175,22.2,20.9,19.875,18.65,16.7,16.825,17.475,19.05,22.0,23.625,21.725,23.05,23.525,22.15,21.975,17.825,16.95,17.8,20.05,21.725,22.275,23.525,20.875,20.175,25.025,24.7,24.1,25.775,26.4,25.65,26.1,25.975,23.5,22.05,20.75,21.5,18.95,17.325,17.200000000000003,18.633333333333333],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Sexe=Ensemble\u003cbr\u003eÂge=25-49 ans\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensemble","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensemble","orientation":"v","showlegend":false,"x":["1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024"],"xaxis":"x3","y":[2.575,2.75,3.025,3.2,3.55,3.625,4.45,4.85,5.025,5.9,6.55,6.9,7.325,7.275,6.975,6.825,7.025,7.85,8.875,9.55,9.05,9.475,9.725,9.3,9.05,7.925,7.225,7.2,7.775,8.025,8.025,7.775,7.15,6.5,7.975,8.225,8.325,8.9,9.4,9.5,9.475,9.1,8.6,8.275,7.55,7.25,7.075,6.575,6.7,6.7],"yaxis":"y3","type":"scatter"},{"hovertemplate":"Sexe=Ensemble\u003cbr\u003eÂge=50 ans ou plus\u003cbr\u003eAnnée=%{x}\u003cbr\u003eTaux de chômage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ensemble","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Ensemble","orientation":"v","showlegend":false,"x":[ ...

# %%
# Calculer la moyenne annuelle par sexe
df_sexe_moyenne_annuelle = df_long.groupby(['Année', 'Sexe'], as_index=False)['Taux'].mean()

# Créer un graphique interactif
fig = px.line(
    df_sexe_moyenne_annuelle,
    x="Année",
    y="Taux",
    color="Sexe",  # Comparaison hommes vs femmes
    markers=True,
    title="Taux de chômage moyen annuel global par sexe (1975-2024)",
    labels={"Année": "Année", "Taux": "Taux de chômage (%)", "Sexe": "Sexe"},
)

# Personnalisation
fig.update_layout(
    xaxis_title="Année",
    yaxis_title="Taux de chômage (%)",
    xaxis=dict(tickangle=45, tickmode="array", tickvals=df_sexe_moyenne_annuelle['Année'][::2]),
    font=dict(family="Arial", size=14),
    plot_bgcolor="white",
    paper_bgcolor="white",
)

# Affichage
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-111175df436e> in <cell line: 2>()
#       1 # Calculer la moyenne annuelle par sexe
# ----> 2 df_sexe_moyenne_annuelle = df_long.groupby(['Année', 'Sexe'], as_index=False)['Taux'].mean()
#       3
#       4 # Créer un graphique interactif
#       5 fig = px.line(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041                 in_axis, level, gpr = False, gpr, None
#    1042             else:
# -> 1043                 raise KeyError(gpr)
#    1044         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045             # Add key to exclusions
#
# KeyError: 'Année'

# %%
import pandas as pd

# Charger le fichier CSV
df_diplome =pd.read_csv('/content/diplome.csv', encoding='Windows-1254', sep=';', on_bad_lines='skip')

# Afficher les premières lignes pour vérifier
print(df_diplome.head())
# Out:
#                     Niveau de diplôme   Taux
# 0  Aucun diplôme, brevet des collèges   13,3
# 1                            CAP, BEP    7,3
# 2                        Baccalauréat    8,8
# 3                     Bac + 2 ou plus      5
# 4                            Ensemble    7,3

# %%
print(df_diplome['Taux'])
# Out:
# 0    13,3
# 1     7,3
# 2     8,8
# 3       5
# 4     7,3
# 5     NaN
# Name: Taux, dtype: object

# %%
# Remplacer les virgules par des points et convertir en numérique
df_diplome['Taux'] = df_diplome['Taux'].str.replace(',', '.').astype(float)

# %%
print(df_diplome['Taux'].head())
# Out:
# 0    13.3
# 1     7.3
# 2     8.8
# 3     5.0
# 4     7.3
# Name: Taux, dtype: float64

# %%
import plotly.express as px

# Création du graphique
fig = px.bar(
    df_diplome,
    x="Niveau de diplôme",
    y="Taux",
    title="Taux de chômage par niveau de diplôme (2023)",
    labels={"Niveau de diplôme": "Niveau de diplôme", "Taux": "Taux de chômage"},
    color="Niveau de diplôme",
    text="Taux"
)

# Personnalisation
fig.update_layout(
    font=dict(size=14, family="Arial"),
    plot_bgcolor="white",
    xaxis_title="Niveau de diplôme",
    yaxis_title="Taux de chômage",
    xaxis_tickangle=45
)
fig.update_traces(texttemplate='%{text:.1f}', textposition='outside')

# Affichage
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-a9f80f417d6a> in <cell line: 4>()
#       2
#       3 # Création du graphique
# ----> 4 fig = px.bar(
#       5     df_diplome,
#       6     x="Niveau de diplôme",
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2115     apply_default_cascade(args)
#    2116
# -> 2117     args = build_dataframe(args, constructor)
#    2118     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119         args = process_dataframe_hierarchy(args)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in build_dataframe(args, constructor)
#    1511     # now that things have been prepped, we do the systematic rewriting of `args`
#    1512
# -> 1513     df_output, wide_id_vars = process_args_into_dataframe(
#    1514         args, wide_mode, var_name, value_name
#    1515     )
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1232                         if argument == "index":
#    1233                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234                         raise ValueError(err_msg)
#    1235                 elif length and len(df_input[argument]) != length:
#    1236                     raise ValueError(
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Niveau de diplôme ', 'Taux'] but received: Niveau de diplôme
